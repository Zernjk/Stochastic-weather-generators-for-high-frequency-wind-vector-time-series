# %%
import torch
import numpy as np
import random
seed=42
# PyTorch
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if using multi-GPU

# Numpy
np.random.seed(seed)

# Python random
random.seed(seed)

# %% [markdown]
# # Weather as Features

# %%
# !python stage1.py --dataset_name 'Wind_wf' --gpu_device_ind 0

# %%
# !python stage2.py --dataset_name_stage1 'Wind_wf' --dataset_name 'Wind_wf' --use_weather_states False --gpu_device_ind 0

# %%
# !python stage2.py --dataset_name_stage1 'Wind_wf' --dataset_name 'Wind_consecutive_wf' --use_weather_states False --consecutive True --gpu_device_ind 0

# %% [markdown]
# # Weather as Embeddings

# %%
# !python stage1.py --dataset_name 'Wind_wsm' --gpu_device_ind 0

# %%
# !python stage2.py --dataset_name_stage1 'Wind_wsm' --dataset_name 'Wind_wsm' --use_weather_states True --weather_states_mask True --gpu_device_ind 0

# %%
# !python stage2.py --dataset_name_stage1 'Wind_wsm' --dataset_name 'Wind_consecutive_wsm' --use_weather_states True --consecutive True --weather_states_mask True --gpu_device_ind 0
